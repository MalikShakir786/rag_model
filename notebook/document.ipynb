# %% [markdown]
# Data Ingestion

# %%
### Document Structure

from langchain_core.documents import Document

document = Document(
    page_content="This is the main content of the document.",
    metadata={
        "source": "document1.txt",
        "pages": 1,
        'author': 'John Doe',
        'date': '2022-01-01'
    },
)
document
# Out:
# Document(metadata={'source': 'document1.txt', 'pages': 1, 'author': 'John Doe', 'date': '2022-01-01'}, page_content='This is the main content of the document.')

# %%
## Create a simple txt file

import os

os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text = {
    "../data/text_files/python_intro.txt": '''
Python is one of the most popular and widely used programming languages in the world. It is known for its simple and readable syntax, which makes it easy for beginners to learn and use. Python was created by Guido van Rossum and first released in 1991. Since then, it has grown into a powerful language used in many different fields.

Python is commonly used for web development, software development, data science, machine learning, artificial intelligence, automation, and cybersecurity. It provides a large number of libraries and frameworks that help developers complete tasks quickly and efficiently. Because of its flexibility and ease of use, Python is used by students, professionals, and major companies around the world.

Another reason for Python’s popularity is its ability to run on different operating systems such as Windows, macOS, and Linux. It also supports multiple programming styles, including object-oriented and functional programming. Overall, Python is an excellent language for anyone who wants to start programming or build modern applications.
''',
"../data/text_files/machine_learning.txt": '''
Machine Learning (ML) is a branch of Artificial Intelligence (AI) that enables computers to learn from data and make decisions or predictions without being explicitly programmed for every task.

Instead of writing fixed rules, we provide data to the system, and it learns patterns from that data. Over time, the system improves its performance as it is exposed to more information.

🤖 How it works

In Machine Learning:

You give the system data
It finds patterns and relationships
It builds a model
The model is used to make predictions or decisions

For example:

Predicting house prices
Recommending products on shopping apps
Detecting spam emails
🔑 Types of Machine Learning
Supervised Learning
The model learns from labeled data (input + correct output).
Example: Predicting exam results based on study hours.
Unsupervised Learning
The model finds hidden patterns in unlabeled data.
Example: Grouping customers based on behavior.
Reinforcement Learning
The model learns by interacting with an environment using rewards and penalties.
Example: Training a game-playing AI.
'''
}

for filepath, content in sample_text.items():
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(content)
    
print("Sample Text files created")
# Out:
# Sample Text files created

# %%
### Text Loader

from langchain_community.document_loaders import TextLoader

loader = TextLoader('../data/text_files/python_intro.txt', encoding='utf-8')
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='\nPython is one of the most popular and widely used programming languages in the world. It is known for its simple and readable syntax, which makes it easy for beginners to learn and use. Python was created by Guido van Rossum and first released in 1991. Since then, it has grown into a powerful language used in many different fields.\n\nPython is commonly used for web development, software development, data science, machine learning, artificial intelligence, automation, and cybersecurity. It provides a large number of libraries and frameworks that help developers complete tasks quickly and efficiently. Because of its flexibility and ease of use, Python is used by students, professionals, and major companies around the world.\n\nAnother reason for Python’s popularity is its ability to run on different operating systems such as Windows, macOS, and Linux. It also supports multiple programming styles, inc
# ...

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader

dirLoader = DirectoryLoader(
    '../data/text_files',
    glob='*.txt',
    loader_cls=TextLoader,
    loader_kwargs={'encoding': 'utf-8'}
)
docs = dirLoader.load()
docs
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='\nPython is one of the most popular and widely used programming languages in the world. It is known for its simple and readable syntax, which makes it easy for beginners to learn and use. Python was created by Guido van Rossum and first released in 1991. Since then, it has grown into a powerful language used in many different fields.\n\nPython is commonly used for web development, software development, data science, machine learning, artificial intelligence, automation, and cybersecurity. It provides a large number of libraries and frameworks that help developers complete tasks quickly and efficiently. Because of its flexibility and ease of use, Python is used by students, professionals, and major companies around the world.\n\nAnother reason for Python’s popularity is its ability to run on different operating systems such as Windows, macOS, and Linux. It also supports multiple programming styles, inc
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

dirLoader = DirectoryLoader(
    '../data/pdf',
    glob='*.pdf',
    loader_cls=PyMuPDFLoader,
)
pdf_docs = dirLoader.load()
type(pdf_docs[0])
# Out:
# langchain_core.documents.base.Document
